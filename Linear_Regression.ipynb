# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
import pandas as pd
df = pd.read_csv('houseprices.csv')
df_5 = df.head()

# %%
# %matplotlib inline 
plt.scatter(df_5.year,df_5.Pcincome, color='red', marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df.Pcincome)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# c:\Users\keerthi\anaconda3\envs\python_course\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575
